# %% [markdown]
# # Notebook to create amplitude versus gamma plot

# %% [markdown]
# ### Download data and uncompress the files into this folder
#
# https://drive.google.com/file/d/1zywc5zUpMSlYDrrdogPEaRd_RTr9U5J6/view?usp=sharing

# %%
# Install the chainconsumer package if it is not already installed
# %pip install 'chainconsumer==0.33.0'
# Out:
# Collecting chainconsumer==0.33.0
#   Downloading ChainConsumer-0.33.0.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from chainconsumer==0.33.0) (1.25.1)
# Requirement already satisfied: scipy in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from chainconsumer==0.33.0) (1.11.1)
# Requirement already satisfied: matplotlib!=2.1.*,!=2.2.*,>1.6.0 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from chainconsumer==0.33.0) (3.7.2)
# Collecting statsmodels>=0.7.0 (from chainconsumer==0.33.0)
#   Downloading statsmodels-0.14.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pandas (from chainconsumer==0.33.0)
#   Downloading pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from matplotlib!=2.1.*,!=2.2.*,>1.6.0->chainconsumer==0.33.0) (2.8.2)
# Collecting patsy>=0.5.6 (from statsmodels>=0.7.0->chainconsumer==0.33.0)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from pandas->chainconsumer==0.33.0) (2024.1)
# Collecting tzdata>=2022.7 (from pandas->chainconsumer==0.33.0)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six in /Users/ved/miniconda3/envs/research/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels>=0.7.0->chainconsumer==0.33.0) (1.16.0)
# Downloading statsmodels-0.14.2-cp311-cp311-macosx_11_0_arm64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 27.6 MB/s eta 0:00:0000:010:01
# Downloading pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 40.2 MB/s eta 0:00:0000:010:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 23.1 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 24.3 MB/s eta 0:00:00
# Building wheels for collected packages: chainconsumer
#   Building wheel for chainconsumer (setup.py) ... done
#   Created wheel for chainconsumer: filename=ChainConsumer-0.33.0-py3-none-any.whl size=42492 sha256=c9a85e0da8625116e3b92774d966547f2eb2e8e9e5b6faac91820e8650ac53ef
#   Stored in directory: /Users/ved/Library/Caches/pip/wheels/09/6f/1e/e824ab61ac7788d1cb2a199f0c083c824cd9d22203325563a2
# Successfully built chainconsumer
# Installing collected packages: tzdata, patsy, pandas, statsmodels, chainconsumer
# Successfully installed chainconsumer-0.33.0 pandas-2.2.2 patsy-0.5.6 statsmodels-0.14.2 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import matplotlib
from chainconsumer import ChainConsumer

# %config InlineBackend.figure_format='retina'
matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %% [markdown]
# ### Plotting specifications

# %%
# 15yr plotting specs
plt.rcParams.update(plt.rcParamsDefault)
with open('../ng15_rcparams.json', 'r') as fin:
    plt.rcParams.update(json.load(fin))
plt.rcParams['text.latex.preamble'] = (
    r'\usepackage{amsmath}'
    r'\usepackage{amsbsy}'
    r'\DeclareMathAlphabet{\mathcal}{OMS}{cmsy}{m}{n}'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 15yr plotting specs
#       2 plt.rcParams.update(plt.rcParamsDefault)
# ----> 3 with open('../ng15_rcparams.json', 'r') as fin:
#       4     plt.rcParams.update(json.load(fin))
#       5 plt.rcParams['text.latex.preamble'] = (
#       6     r'\usepackage{amsmath}'
#       7     r'\usepackage{amsbsy}'
#       8     r'\DeclareMathAlphabet{\mathcal}{OMS}{cmsy}{m}{n}'
#       9 )
#
# File ~/miniconda3/envs/research/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../ng15_rcparams.json'

# %% [markdown]
# ### Read in long HD chains for fixed and varied gamma.
#
# These are concatenated from runs by William Lamb and Nihan Pol.

# %%
datapath = './figure1_data/'

# %% [markdown]
# #### Varied gamma

# %%
hd_chain = np.load(datapath + 'nano15_hd_chain_long_050523.npy')

# %%
print(hd_chain)
print(np.shape(hd_chain))
# Out:
# [[  2.78156254 -14.06335738]
#  [  2.98472966 -14.06642007]
#  [  2.65575301 -14.06642007]
#  ...
#  [  3.54812321 -14.38181004]
#  [  3.54812321 -14.38181004]
#  [  3.54812321 -14.38181004]]
# (143824, 2)

# %%
## amp
print(10**np.percentile(hd_chain[:,1],q=5),#-10**np.percentile(hd_chain[:,1],q=50), 
      10**np.percentile(hd_chain[:,1],q=95),#-10**np.percentile(hd_chain[:,1],q=50), 
      10**np.percentile(hd_chain[:,1],q=50))
## gamma
print(np.percentile(hd_chain[:,0],q=5),#-np.percentile(hd_chain[:,0],q=50), 
      np.percentile(hd_chain[:,0],q=95),#-np.percentile(hd_chain[:,0],q=50), 
      np.percentile(hd_chain[:,0],q=50))
# Out:
# 3.699923194590101e-15 1.0558530221516469e-14 6.385420941789065e-15
# 2.659568427502257 3.839771874796981 3.2476865997217192

# %% [markdown]
# #### Fixed gamma=13/3

# %%
hd_chain_fg = np.load(datapath + 'nano15_hd_chain_fg_long_050523.npy')

# %%
print(10**np.percentile(hd_chain_fg,q=5), 
      10**np.percentile(hd_chain_fg,q=95), 
      10**np.percentile(hd_chain_fg,q=50))
# Out:
# 1.815211583802292e-15 3.0689227094055674e-15 2.403918137658136e-15

# %%
print(10**np.percentile(hd_chain_fg,q=5)-10**np.percentile(hd_chain_fg,q=50), 
      10**np.percentile(hd_chain_fg,q=95)-10**np.percentile(hd_chain_fg,q=50))
# Out:
# -5.887065538558439e-16 6.650045717474314e-16

# %%
tmp_chain_fg = hd_chain_fg.copy()
# updating amplitude to be referenced to lower frequency
correction_factor = 0.5 * (3-(13./3.)) * np.log10(0.1)
tmp_chain_fg = correction_factor + tmp_chain_fg

# %%
print(10**np.percentile(tmp_chain_fg,q=5), 
      10**np.percentile(tmp_chain_fg,q=95), 
      10**np.percentile(tmp_chain_fg,q=50))
# Out:
# 8.425465818021274e-15 1.4244677379197537e-14 1.1157999584673217e-14

# %%
from matplotlib.ticker import FormatStrFormatter

labs = [r'$\gamma_\mathrm{GWB}$', 
        r'$\log_{10}A_\mathrm{GWB}$']

c = ChainConsumer()
c.add_chain(hd_chain,
          weights=None,
          parameters=labs, 
          zorder=2, name='$f_\mathrm{ref}$ = $1\,\, \mathrm{yr}^{-1}\quad 32\,\,\mathrm{nHz}$')


# reference frequency = 1 / 10yr 
# tmp_chain = hd_chain.copy()
# # updating amplitude to be referenced to lower frequency
# correction_factor = 0.5 * (3-tmp_chain[:,0]) * np.log10(0.1)
# tmp_chain[:,1] = correction_factor + tmp_chain[:,1]


# c.add_chain(tmp_chain,
#           weights=None,
#           parameters=labs, 
#           zorder=1, name='$f_\mathrm{ref}$ = $0.1\,\, \mathrm{yr}^{-1}\quad 3.2\,\,\mathrm{nHz}$')

c.configure(usetex=True, 
            bar_shade=[False, False],
            colors=['blue', 'orange'],
           linestyles=['solid', 'solid'],
           linewidths=[1.0,0.9],
           shade=[True,False], 
            shade_alpha=[0.05, 0.0],
            summary=False,
            smooth=50.0,
            diagonal_tick_labels=False,
           legend_kwargs={'loc':(0.03,0.05), 'handlelength':0, 
                          'markerfirst':True, 'fontsize':'small'},
           sigmas=[0,1,2,3], 
            shade_gradient=0.0)

fig = c.plotter.plot(truth=[4.333,-12],
                     extents=[(2, 4.5), (-14.8, -13.7)],
                    figsize=(3.5503666805036667, 2.1942472810764047)) 
fig.axes[2].minorticks_on()
fig.axes[2].tick_params(which='both',direction='in',tick2On=True)
fig.axes[2].set_yticklabels(fig.axes[2].get_yticklabels(),rotation=45)
fig.axes[2].set_yticks([-14.8,-14.6,-14.4,-14.2,-14.0,-13.8])
fig.axes[2].yaxis.set_major_formatter(FormatStrFormatter('$%.1f$'))

fig.axes[0].set_xlim(fig.axes[2].get_xlim())
fig.axes[0].set_xticks(fig.axes[2].get_xticks()[:-1])
fig.axes[0].minorticks_on()
fig.axes[0].tick_params(which='both',direction='in',top=True,
                        labeltop=False,bottom=True,labelbottom=False)

# fig.axes[3].set_yticks(fig.axes[2].get_yticks()[:-1])
# fig.axes[3].set_xlim(0,6.)
# fig.axes[3].minorticks_on()
# fig.axes[3].tick_params(which='both',direction='in',right=True,
#                         labelright=False,left=True,labelleft=False)
# fig.axes[3].hist(hd_chain_fg,density=True,color='C0',histtype='step',
#                  ls='dashed',lw=0.9,orientation='horizontal',bins=60)
# fig.axes[3].hist(tmp_chain_fg,density=True,color='C1',histtype='step',
#                  ls='dashed',lw=0.9,orientation='horizontal',bins=60)

plt.show()
#plt.savefig('nano15_14f_cornerplot_2amps_vg_fg_050523.pdf',bbox_inches='tight',dpi=400)
# Out:
# /var/folders/n0/6lc5_8690gz45p4xcxg6tcg40000gn/T/ipykernel_70358/573974910.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig.axes[2].set_yticklabels(fig.axes[2].get_yticklabels(),rotation=45)
